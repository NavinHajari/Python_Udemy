# %% [markdown]
# Variable: Naming Values

# %%
var1 = "hello"

# %%
var1
# Out:
# 'hello'

# %%
item = 101
print (type(item))
# Out:
# <class 'int'>

# %%
item = "Code 101"
print (type(item))
# Out:
# <class 'str'>
